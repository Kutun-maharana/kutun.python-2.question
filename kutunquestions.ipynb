# %% [markdown]
# <a href="https://colab.research.google.com/github/Kutun-maharana/kutun.python-2.question/blob/main/kutunquestions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student_name = input("Enter a student name: ") #Accept a student name and diplay it in uppercase
print(student_name.upper())
# Out:
# Enter a student name: kutun
# KUTUN

# %%
city_name = input("Enter a city name : ")  #acccpet city name,in upper case, in lower case, in title
print(city_name)
print(city_name.upper())
print(city_name.lower())
print(city_name.title())
# Out:
# Enter a city name : rourkela
# rourkela
# ROURKELA
# rourkela
# Rourkela

# %%
name = input("Enter a string : ")  #accept a string and display its first and last character
print(name [0])
print(name[-1])
# Out:
# Enter a string : KUTUN
# K
# N

# %%
text=input("Enter a string : ")  #length of the text
print(len(text))
# Out:
# Enter a string : PradeepKunni
# 12

# %%
name=input("enter a string : ")  #count the input string
print(name.count('a'))
# Out:
# enter a string : Pranak
# 2

# %%
name=input("enter a string : ")
print(name.replace('python','AI'))
# Out:
# enter a string : python is a programing language
# AI is a programing language

# %%
email=input("enter ur email : ")
if email.endswith("@gmail.com"):
    print("Valid Gmail address")
else:
    print("not a Gmail adress")
# Out:
# enter ur email : kutun@gmail.com
# Valid Gmail address

# %%
name= input("enter value : ")
if name.isdigit():
  print("contains only digit")
else:
  print("contains other character")
# Out:
# enter value : 456788
# contains only digit

# %%
text= input("enter a valid : ")
if text.isalpha():
  print("contains only alphabates")
else:
  print("contains other character")
# Out:
# enter a valid : kioplmnhh
# contains only alphabates

# %%
fruits ="apple, mango, banana, grapes"
list= fruits.split(",")
print(list)
# Out:
# ['apple', ' mango', ' banana', ' grapes']

# %%
age= int(input("enter age : "))
if age>=18:
   print("you are eligible for vote")
else:
   print("you are not eligible for vote")
# Out:
# enter age : 65
# you are eligible for vote

# %%
number = int(input("enter a number : "))
if number>0:
   print("it is a positive number")
else:
   if number<0:
      print("it is a negative number")
   if number==0:
      print("it is zero")
# Out:
# enter a number : 0
# it is zero

# %%
first_number = int(input("the first number is : "))
second_number = int(input("the second number is : "))
if first_number > second_number:
  print("greater number is  ",first_number)
else:
  print("greater number is ",second_number)
# Out:
# the first number is : 54
# the second number is : 67
# greater number is  67

# %%
number = int(input("put a number : "))
if number % 2==0:
   print("even number")
else:
   print("odd number")
# Out:
# put a number : 45
# odd number

# %%
marks = int(input("Enter marks: "))

if marks >= 90:
    print("Grade A")
elif marks >= 75:
    print("Grade B")
elif marks >= 50:
    print("Grade C")
else:
    print("Fail")
# Out:
# Enter marks: 45
# Fail

# %%
password = input("Enter password: ")

if len(password) >= 8:
    print("Strong Password")
else:
    print("Weak Password")
# Out:
# Enter password: ty@--huji_ok
# Strong Password

# %%
year = int(input("Enter year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter year: 2028
# Leap Year

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
num3 = int(input("Enter third number: "))

largest = max(num1, num2, num3)

print("Largest Number:", largest)
3
# Out:
# Enter first number: 12
# Enter second number: 4
# Enter third number: 56
# Largest Number: 56

# %%
username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "1234":
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Enter username: admin
# Enter password: 1234
# Login Successful

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operator = input("Enter operator (+, -, *, /): ")

if operator == "+":
    print("Result:", num1 + num2)
elif operator == "-":
    print("Result:", num1 - num2)
elif operator == "*":
    print("Result:", num1 * num2)
elif operator == "/":
    print("Result:", num1 / num2)
else:
    print("Invalid Operator")
# Out:
# Enter first number: 23
# Enter second number: 5
# Enter operator (+, -, *, /): *
# Result: 115.0

# %%
a = [1,2,3]
b = a
b.append(4)
print(a)
# Out:
# [1, 2, 3, 4]

# %%
x = 0
for i in range(3):   #for else loop
    x += i
    if i == 1:
      break
else:
    x +=100
print(x)
# Out:
# 1

# %%
x = 0
for i in range(3):  #ifelse loop
    x += i
    if i == 1:
      break
    else:
      x +=100
print(x)
# Out:
# 101

# %%
i = 0

while i < 5:
  if i ==3:
    i +=2
    continue

  print("hello")
  i += 1
# Out:
# hello
# hello
# hello

# %%
def f(x, lst=[]):
    lst.append(x)
    return lst
print(f(1))
print(f(2))
print(f(3))
# Out:
# [1]
# [1, 2]
# [1, 2, 3]

# %%
count = 1

while count < 4:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3

# %%
point = (10,20)
print(point)

x,y = point
print(x)
print(y)
# Out:
# (10, 20)
# 10
# 20

# %%
point = (10,20,30,40)
print(point)

x, *y = point
print(x)
print(y)
# Out:
# (10, 20, 30, 40)
# 10
# [20, 30, 40]

# %%
point = (10,20,30,40)
print(point)

*x, y = point
print(x)
print(y)
# Out:
# (10, 20, 30, 40)
# [10, 20, 30]
# 40

# %%
point = (10,20,30,40)
print(point)

x, *y,y1, z = point
print(x)
print(y)
print(y1)
print(z)
# Out:
# (10, 20, 30, 40)
# 10
# [20]
# 30
# 40

# %%
a, b = 5,10
a, b = b, a
print(a, b)
# Out:
# 10 5
